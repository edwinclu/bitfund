# %%
import lib.data_source as data_source
import lib.df_util as df_util
import lib.df_plot as df_plot
import datetime

BEGIN_DATE_TIME = datetime.datetime(2018, 9, 1)
END_DATE_TIME = datetime.datetime(2020, 8, 30)

QQQ_df = data_source.get_daily_quotes('QQQ', BEGIN_DATE_TIME, END_DATE_TIME)
ticker_df = data_source.get_quotes('TSLA', BEGIN_DATE_TIME, END_DATE_TIME)
ticker_df, QQQ_df = df_util.align_dfs(ticker_df, QQQ_df)
# Out:
# getting quotes
# QQQ :  2019-12-12 00:00:00 ... 2020-08-28    1
# QQQ :  2019-03-28 00:00:00 ... 2019-12-11    2
# QQQ :  2018-07-10 00:00:00 ... 2019-03-27    3
# getting quotes
# TSLA :  2019-12-12 00:00:00 ... 2020-08-28    1
# TSLA :  2019-03-28 00:00:00 ... 2019-12-11    2
# TSLA :  2018-07-10 00:00:00 ... 2019-03-27    3

# %%
# %matplotlib widget
df_plot.plot_price([ticker_df, QQQ_df], ['TSLA', 'QQQ'], price_key='close')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (<Figure size 640x480 with 1 Axes>,
#  <AxesSubplot:xlabel='Time', ylabel='Price'>)
